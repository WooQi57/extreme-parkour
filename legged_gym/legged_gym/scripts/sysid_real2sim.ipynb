# %%
import numpy as np
import matplotlib.pyplot as plt
torques = np.load("../figs/torques.npy")

# %%
plt.plot(torques[:,7])

# %%
import numpy as np
import matplotlib.pyplot as plt
hist_latent_real = np.load("../figs/sysid/hist_latent.npy")

# %%
plt.plot(hist_latent_real[:,15])

# %%
import numpy as np
import matplotlib.pyplot as plt
real_data = np.load("../figs/sysid/real_data4012.npz")
r_dof = real_data['dof_hist']

r_dof3006 = np.load("../figs/sysid/real_data3006.npz")['dof_hist']
r_dof4008 = np.load("../figs/sysid/real_data4008.npz")['dof_hist']
r_dof3006_4 = np.load("../figs/sysid/real_data3006_4.npz")['dof_hist']
r_dof3006_5 = np.load("../figs/sysid/real_data3006_5.npz")['dof_hist']
r_dof3006_11 = np.load("../figs/sysid/real_data3006_11.npz")['dof_hist']
r_dof3006_1 = np.load("../figs/sysid/real_data3006_1.npz")['dof_hist']
r_dof3204_4 = np.load("../figs/sysid/real_data3204_4.npz")['dof_hist']
r_dof3204_5 = np.load("../figs/sysid/real_data3204_5.npz")['dof_hist']
r_dof3204_1 = np.load("../figs/sysid/real_data3204_1.npz")['dof_hist']
r_dof4012_4 = np.load("../figs/sysid/real_data4012_4.npz")['dof_hist']
s_dof = np.load("../figs/sysid/q2_sim_original.npz")['dof_hist']
s_dof_4 = np.load("../figs/sysid/q4_sim.npz")['dof_hist']
s_dof_5 = np.load("../figs/sysid/q5_sim.npz")['dof_hist']
s_dof_11 = np.load("../figs/sysid/q11_sim.npz")['dof_hist']
s_dof_1 = np.load("../figs/sysid/q1_sim.npz")['dof_hist']

# %%
joint_id = 8
s_dof_8 = np.load("../figs/sysid/q8_sim.npz")['dof_hist']
r_dof3006_8 = np.load("../figs/sysid/real_data3006_8.npz")['dof_hist']

plt.plot(s_dof_8[45:50+18, joint_id], label='sim_8')
plt.plot(r_dof3006_8[20:25+18, joint_id], label='real3006')
# plt.plot(r_dof3204_5[20:25+18, joint_id], label='real3204')
plt.legend()
plt.grid(True)

# %%
joint_id = 11
plt.plot(s_dof_11[45:50+18, joint_id], label='sim_11')
plt.plot(r_dof3006_11[20:25+18, joint_id], label='real3006')
# plt.plot(r_dof3204_5[20:25+18, joint_id], label='real3204')
plt.legend()
plt.grid(True)

# %%
joint_id = 5
plt.plot(s_dof_5[45:50+18, joint_id], label='sim_5')
plt.plot(r_dof3006_5[20:25+18, joint_id], label='real3006')
plt.plot(r_dof3204_5[20:25+18, joint_id], label='real3204')
plt.legend()
plt.grid(True)

# %%
joint_id = 1
plt.plot(s_dof_1[45:50+18, joint_id], label='sim_1')
plt.plot(r_dof3006_1[20:25+18, joint_id], label='real3006')
plt.plot(r_dof3204_1[20:25+18, joint_id], label='real3204')
plt.legend()
plt.grid(True)

# %%
joint_id = 4
plt.plot(s_dof_4[45:50+18, joint_id], label='sim_4')
plt.plot(r_dof3006_4[20:25+18, joint_id], label='real3006')
plt.plot(r_dof3204_4[20:25+18, joint_id], label='real3204')
plt.plot(r_dof4012_4[20:25+18, joint_id], label='real4012')
plt.legend()
plt.grid(True)

# %%
joint_id = 2
plt.plot(s_dof[45:50+18, joint_id], label='sim')
plt.plot(r_dof[20:25+18, joint_id], label='real4012')
plt.plot(r_dof4008[20:25+18, joint_id], label='real4008')
plt.plot(r_dof3006[45:50+18, joint_id], label='real3006')
plt.legend()
plt.grid(True)
